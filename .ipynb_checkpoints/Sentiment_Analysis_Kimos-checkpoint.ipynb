# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob
import spacy
from spacy.matcher import Matcher
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.probability import FreqDist
from collections import Counter
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sayhi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
reviews = pd.read_csv('yelp_kimos.csv')

# %%
reviews = reviews[:-1]
reviews
# Out:
#             Date           Rating  \
# 0      9/28/2017  4.0 star rating
# 1      9/19/2017  5.0 star rating
# 2      9/17/2017  3.0 star rating
# 3      8/31/2017  5.0 star rating
# 4      9/22/2017  4.0 star rating
# ...          ...              ...
# 2075  10/28/2008  4.0 star rating
# 2076   9/17/2009  5.0 star rating
# 2077   2/18/2009  4.0 star rating
# 2078  10/14/2007  5.0 star rating
# 2079   1/23/2010  5.0 star rating
#
#                                                  Review        Name  \
# 0     I  really liked their menu set up. Fresh fish ...      Amy E.
# 1     Went for dinner on our 1st night in Maui..my s...     Jill C.
# 2     Beautiful beachfront restaurant in Lahaina tow...   Saleen D.
# 3     One of my My favorite restaurants in Maui  wit...    Amber V.
# 4     After lunch, we wanted to go people watch on t...      Dan O.
# ...                                                 ...         ...
# 2075  Okay so I used to work here, I'm completely bi...   Audrey S.
# 2076  For our first family trip to the neighbor isla...  Leilani D.
# 2077  Kimo's has one of the best spots to watch the ...     Matt P.
# 2078  Lunch.  Fish sandwich - Kimo's style (not spic...   Kanani P.
# 2079  Excellent dinners; very tasty, excellent servi...   Debbie F.
#
#                       Location        Rating_v1
# 0                  Fremont, CA  4.0 star rating
# 1     Puerto Real, Puerto Rico  4.0 star rating
# 2                San Diego, CA  4.0 star rating
# 3                Las Vegas, NV  4.0 star rating
# 4          Madison Heights, MI  4.0 star rating
# ...                        ...              ...
# 2075               Lahaina, HI  4.0 star rating
# 2076               Waianae, HI  4.0 star rating
# 2077           Los Angeles, CA  4.0 star rating
# 2078         San Francisco, CA  4.0 star rating
# 2079        Central Valley, CA  4.0 star rating
#
# [2080 rows x 6 columns]

# %%
reviews['Rating'].value_counts().plot(kind='bar', figsize=(14,8));

# %%
reviews['Review'] = reviews['Review'].astype(str)
reviews['Rating'] = reviews['Rating'].str[:1].astype(int)

# %%
#Lowercasing all the review content to make data normalised and keep words in uniform manner
reviews['Review'] = reviews['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
#removing special characters: Since these special characters create their own tokens and hence not usefull in any kind of 
#algorithm
reviews['review_new'] = reviews['Review'].str.replace('[^\w\s]','')

# %%
#removing stopwords from the reviews, because there words have no predictive power in reality
# for example: i, me, myself
stop = stopwords.words('english')
reviews['review_new'] = reviews['review_new'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
#Stemming: helps to gain relevant information as it reduces all words with the same roots to a 
#common form by removing suffixes such as -action, ing, -es and -ses.
#BUT  there can be problematic where there are spelling errors.

st = PorterStemmer()
reviews['review_stemmer'] = reviews['review_new'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))


#LEMMATIZING: creates a common word reducing the use of tenses which likely removes suffixes
lem = WordNetLemmatizer()
reviews['review_lemmatizer'] = reviews['review_new'].apply(lambda x: " ".join([lem.lemmatize(word) for word in x.split()]))

# %%
reviews
# Out:
#             Date  Rating                                             Review  \
# 0      9/28/2017       4  i really liked their menu set up. fresh fish s...
# 1      9/19/2017       5  went for dinner on our 1st night in maui..my s...
# 2      9/17/2017       3  beautiful beachfront restaurant in lahaina tow...
# 3      8/31/2017       5  one of my my favorite restaurants in maui with...
# 4      9/22/2017       4  after lunch, we wanted to go people watch on t...
# ...          ...     ...                                                ...
# 2075  10/28/2008       4  okay so i used to work here, i'm completely bi...
# 2076   9/17/2009       5  for our first family trip to the neighbor isla...
# 2077   2/18/2009       4  kimo's has one of the best spots to watch the ...
# 2078  10/14/2007       5  lunch. fish sandwich - kimo's style (not spicy...
# 2079   1/23/2010       5  excellent dinners; very tasty, excellent servi...
#
#             Name                  Location        Rating_v1  \
# 0         Amy E.               Fremont, CA  4.0 star rating
# 1        Jill C.  Puerto Real, Puerto Rico  4.0 star rating
# 2      Saleen D.             San Diego, CA  4.0 star rating
# 3       Amber V.             Las Vegas, NV  4.0 star rating
# 4         Dan O.       Madison Heights, MI  4.0 star rating
# ...          ...                       ...              ...
# 2075   Audrey S.               Lahaina, HI  4.0 star rating
# 2076  Leilani D.               Waianae, HI  4.0 star rating
# 2077     Matt P.           Los Angeles, CA  4.0 star rating
# 2078   Kanani P.         San Francisco, CA  4.0 star rating
# 2079   Debbie F.        Central Valley, CA  4.0 star rating
#
#                                              review_new  \
# 0     really liked menu set fresh fish selection cha...
# 1     went dinner 1st night mauimy son 15 loves cook...
# 2     beautiful beachfront restaurant lahaina town b...
# 3     one favorite restaurants maui view food die ob...
# 4     lunch wanted go people watch boardwalk later g...
# ...                                                 ...
# 2075  okay used work im completely biased eaten ever...
# 2076  first family trip neighbor island maui place m...
# 2077  kimos one best spots watch sunset lounge area ...
# 2078  lunch fish sandwich kimos style spicy cajun st...
# 2079  excellent dinners tasty excellent service mang...
#
#                                          review_stemmer  \
# 0     realli like menu set fresh fish select chang d...
# 1     went dinner 1st night mauimi son 15 love cook ...
# 2     beauti beachfront restaur lahaina town beauti ...
# 3     one favorit restaur maui view food die obvious...
# 4     lunch want go peopl watch boardwalk later grab...
# ...                                                 ...
# 2075  okay use work im complet bias eaten everyth me...
# 2076  first famili trip neighbor island maui place m...
# 2077  kimo one best spot watch sunset loung area cre...
# 2078  lunch fish sandwich kimo style spici cajun sty...
# 2079  excel dinner tasti excel servic mango daiquiri...
#
#                                       review_lemmatizer
# 0     really liked menu set fresh fish selection cha...
# 1     went dinner 1st night mauimy son 15 love cook ...
# 2     beautiful beachfront restaurant lahaina town b...
# 3     one favorite restaurant maui view food die obv...
# 4     lunch wanted go people watch boardwalk later g...
# ...                                                 ...
# 2075  okay used work im completely biased eaten ever...
# 2076  first family trip neighbor island maui place m...
# 2077  kimos one best spot watch sunset lounge area c...
# 2078  lunch fish sandwich kimos style spicy cajun st...
# 2079  excellent dinner tasty excellent service mango...
#
# [2080 rows x 9 columns]

# %%
#the first score is sentiment polarity which tells if the sentiment is positive or negative 
#and the second score is subjectivity score to tell how subjective is the text
def sentiment(x):
    return TextBlob(x).sentiment  

reviews['review_score'] = reviews['review_new'].apply(sentiment)

reviews
# Out:
#             Date  Rating                                             Review  \
# 0      9/28/2017       4  i really liked their menu set up. fresh fish s...
# 1      9/19/2017       5  went for dinner on our 1st night in maui..my s...
# 2      9/17/2017       3  beautiful beachfront restaurant in lahaina tow...
# 3      8/31/2017       5  one of my my favorite restaurants in maui with...
# 4      9/22/2017       4  after lunch, we wanted to go people watch on t...
# ...          ...     ...                                                ...
# 2075  10/28/2008       4  okay so i used to work here, i'm completely bi...
# 2076   9/17/2009       5  for our first family trip to the neighbor isla...
# 2077   2/18/2009       4  kimo's has one of the best spots to watch the ...
# 2078  10/14/2007       5  lunch. fish sandwich - kimo's style (not spicy...
# 2079   1/23/2010       5  excellent dinners; very tasty, excellent servi...
#
#             Name                  Location        Rating_v1  \
# 0         Amy E.               Fremont, CA  4.0 star rating
# 1        Jill C.  Puerto Real, Puerto Rico  4.0 star rating
# 2      Saleen D.             San Diego, CA  4.0 star rating
# 3       Amber V.             Las Vegas, NV  4.0 star rating
# 4         Dan O.       Madison Heights, MI  4.0 star rating
# ...          ...                       ...              ...
# 2075   Audrey S.               Lahaina, HI  4.0 star rating
# 2076  Leilani D.               Waianae, HI  4.0 star rating
# 2077     Matt P.           Los Angeles, CA  4.0 star rating
# 2078   Kanani P.         San Francisco, CA  4.0 star rating
# 2079   Debbie F.        Central Valley, CA  4.0 star rating
#
#                                              review_new  \
# 0     really liked menu set fresh fish selection cha...
# 1     went dinner 1st night mauimy son 15 loves cook...
# 2     beautiful beachfront restaurant lahaina town b...
# 3     one favorite restaurants maui view food die ob...
# 4     lunch wanted go people watch boardwalk later g...
# ...                                                 ...
# 2075  okay used work im completely biased eaten ever...
# 2076  first family trip neighbor island maui place m...
# 2077  kimos one best spots watch sunset lounge area ...
# 2078  lunch fish sandwich kimos style spicy cajun st...
# 2079  excellent dinners tasty excellent service mang...
#
#                                          review_stemmer  \
# 0     realli like menu set fresh fish select chang d...
# 1     went dinner 1st night mauimi son 15 love cook ...
# 2     beauti beachfront restaur lahaina town beauti ...
# 3     one favorit restaur maui view food die obvious...
# 4     lunch want go peopl watch boardwalk later grab...
# ...                                                 ...
# 2075  okay use work im complet bias eaten everyth me...
# 2076  first famili trip neighbor island maui place m...
# 2077  kimo one best spot watch sunset loung area cre...
# 2078  lunch fish sandwich kimo style spici cajun sty...
# 2079  excel dinner tasti excel servic mango daiquiri...
#
#                                       review_lemmatizer  \
# 0     really liked menu set fresh fish selection cha...
# 1     went dinner 1st night mauimy son 15 love cook ...
# 2     beautiful beachfront restaurant lahaina town b...
# 3     one favorite restaurant maui view food die obv...
# 4     lunch wanted go people watch boardwalk later g...
# ...                                                 ...
# 2075  okay used work im completely biased eaten ever...
# 2076  first family trip neighbor island maui place m...
# 2077  kimos one best spot watch sunset lounge area c...
# 2078  lunch fish sandwich kimos style spicy cajun st...
# 2079  excellent dinner tasty excellent service mango...
#
#                                    review_score
# 0                   (0.3596590909090908, 0.575)
# 1                                (0.75, 0.5875)
# 2     (0.20606060606060603, 0.6450757575757576)
# 3                   (0.24363636363636365, 0.59)
# 4      (0.3017857142857143, 0.3834325396825397)
# ...                                         ...
# 2075   (0.4611542443064182, 0.5409247757073843)
# 2076   (0.2826704545454546, 0.5187499999999999)
# 2077  (0.23190476190476192, 0.4373015873015873)
# 2078            (-0.002499999999999991, 0.5575)
# 2079                             (0.752, 0.808)
#
# [2080 rows x 10 columns]

# %%
reviews[['polarity', 'subjectivity']] = pd.DataFrame(reviews['review_score'].tolist(), index=reviews.index)

# %%
reviews['polarity'].plot(figsize=(18,8));
plt.title('Review Polarity Score',fontsize = 20);
plt.axhline(y=0, linewidth=4, color='r');

# %%
reviews['subjectivity'].plot(figsize=(18,8));
plt.title('Review Subjectivity Score',fontsize = 20);
plt.axhline(y=0, linewidth=4, color='r');

# %%
nlp = spacy.load("en_core_web_sm")
analyser = SentimentIntensityAnalyzer()

# %%
def neg_terms(x):
    neg_wrd = []
    text = x.split('.')
    for i in text:    
        doc = nlp(i)    
        for tok in doc: 
            if tok.pos_ == 'ADJ' or tok.pos_ == 'VERB':
                pol = analyser.polarity_scores(tok.text)
                if pol.get('neg') > pol.get('pos'):
                    neg_wrd.append(tok.text)
    return neg_wrd
                    
reviews['Negative Terms'] = reviews['review_new'].apply(neg_terms)

# %%
def pos_terms(x):
    pos_wrd = []
    text = x.split('.')
    for i in text:    
        doc = nlp(i)    
        for tok in doc: 
            if tok.pos_ == 'ADJ' or tok.pos_ == 'VERB':
                pol = analyser.polarity_scores(tok.text)
                if pol.get('neg') < pol.get('pos'):
                    pos_wrd.append(tok.text)
    return pos_wrd
                    
reviews['Positive Terms'] = reviews['review_new'].apply(pos_terms)

# %%
asp_ss = [] #Super set of aspect terms to be used in wordcloud later
def asp_terms(x):
    asp_wrd = []
    text = x.split('.')
    for i in text:    
        doc = nlp(i)    
        for tok in doc: 
            if tok.pos_ == 'NOUN' or tok.pos_ == 'PRONOUN':
                    asp_wrd.append(tok.text)
                    asp_ss.append(tok.text)
    return asp_wrd
                    
reviews['Aspect Terms'] = reviews['review_new'].apply(asp_terms)

# %%
reviews.head()
# Out:
#         Date  Rating                                             Review  \
# 0  9/28/2017       4  i really liked their menu set up. fresh fish s...
# 1  9/19/2017       5  went for dinner on our 1st night in maui..my s...
# 2  9/17/2017       3  beautiful beachfront restaurant in lahaina tow...
# 3  8/31/2017       5  one of my my favorite restaurants in maui with...
# 4  9/22/2017       4  after lunch, we wanted to go people watch on t...
#
#         Name                  Location        Rating_v1  \
# 0     Amy E.               Fremont, CA  4.0 star rating
# 1    Jill C.  Puerto Real, Puerto Rico  4.0 star rating
# 2  Saleen D.             San Diego, CA  4.0 star rating
# 3   Amber V.             Las Vegas, NV  4.0 star rating
# 4     Dan O.       Madison Heights, MI  4.0 star rating
#
#                                           review_new  \
# 0  really liked menu set fresh fish selection cha...
# 1  went dinner 1st night mauimy son 15 loves cook...
# 2  beautiful beachfront restaurant lahaina town b...
# 3  one favorite restaurants maui view food die ob...
# 4  lunch wanted go people watch boardwalk later g...
#
#                                       review_stemmer  \
# 0  realli like menu set fresh fish select chang d...
# 1  went dinner 1st night mauimi son 15 love cook ...
# 2  beauti beachfront restaur lahaina town beauti ...
# 3  one favorit restaur maui view food die obvious...
# 4  lunch want go peopl watch boardwalk later grab...
#
#                                    review_lemmatizer  \
# 0  really liked menu set fresh fish selection cha...
# 1  went dinner 1st night mauimy son 15 love cook ...
# 2  beautiful beachfront restaurant lahaina town b...
# 3  one favorite restaurant maui view food die obv...
# 4  lunch wanted go people watch boardwalk later g...
#
#                                 review_score  polarity  subjectivity  \
# 0                (0.3596590909090908, 0.575)  0.359659      0.575000
# 1                             (0.75, 0.5875)  0.750000      0.587500
# 2  (0.20606060606060603, 0.6450757575757576)  0.206061      0.645076
# 3                (0.24363636363636365, 0.59)  0.243636      0.590000
# 4   (0.3017857142857143, 0.3834325396825397)  0.301786      0.383433
#
#       Negative Terms                                     Positive Terms  \
# 0        [stressful]                  [liked, fresh, great, sweet, lol]
# 1                 []                         [loves, best, outstanding]
# 2            [wrong]  [beautiful, thank, gorgeous, friendly, good, p...
# 3  [die, crash, die]  [favorite, want, fresh, wonderful, enjoying, r...
# 4                 []                                [great, sure, love]
#
#                                         Aspect Terms
# 0  [menu, fish, selection, day, preparation, port...
# 1  [dinner, night, restaurants, fish, caper, sauc...
# 2  [town, restaurant, reservation, dine, table, v...
# 3  [restaurants, view, food, fish, steaks, dishes...
# 4  [lunch, people, drink, door, pavaillion, water...

# %%
#Frequency Distribution for Wordcloud
fdist = FreqDist(asp_ss)
topterms = fdist.most_common(50)

# %%
# concatenating the top terms from the list to be passed onto the wordcloud
term_str = ' '
for a, c in topterms:
    term_str = term_str + a + ' '

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white', 
                      max_words=300).generate(term_str)
plt.imshow(wordcloud)
wordcloud.to_file("wordcloud_aspect_terms.png")
plt.tight_layout()
plt.axis("off")
plt.show()

# %%
#Definig a pattern for words to retrieve the required N-grams
ngrams_wc = []
def sp_pattern(x):
    ngrams_ss = []
    n_g = []
    n_g1 = []
    n_g2 = []
    n_g3 = []
    n_g4 = []
    n_g5 = []
    matcher = Matcher(nlp.vocab)
    text = x.split('.')
    for i in text:    
        doc = nlp(i)    
        pattern = [
                {'POS': 'VERB'}, 
                {'POS': 'NOUN'},
                {'POS': 'NOUN', 'OP': '?'},
                ]

        pattern1 = [
                {'POS': 'ADJ'}, 
                {'POS': 'NOUN'},
                {'POS': 'NOUN', 'OP': '?'},
                ]

        pattern2 = [
                {'DEP': 'ROOT', 'OP': '?'},
                {'POS': 'ADJ'}, 
                {'POS': 'PROPN'},
                ]

        pattern3 = [
                {'POS': 'ADJ'}, 
                {'POS': 'VERB'},
                ]

        pattern4 = [
                {'POS': 'PROPN', 'OP': '?'}, 
                {'POS': 'NOUN'},
                {'POS': 'ADJ'},
                ]

        pattern5 = [ 
                {'POS': 'VERB'},
                {'POS': 'PROPN'},
                ]
        
        matcher.add('PATTERN', None, pattern)

        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                n_g.append(ngrams.lemma_)
                ngrams_ss.append(ngrams.lemma_)
                ngrams_wc.append(ngrams.lemma_)
 
        matcher.add('PATTERN1', None, pattern1)
        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                if ngrams.lemma_ not in n_g:
                    n_g1.append(ngrams.lemma_)
                    ngrams_ss.append(ngrams.lemma_)
                    ngrams_wc.append(ngrams.lemma_)

        matcher.add('PATTERN2', None, pattern2)
        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                if ngrams.lemma_ not in n_g and ngrams.lemma_ not in n_g1:
                    n_g2.append(ngrams.lemma_)
                    ngrams_ss.append(ngrams.lemma_)
                    ngrams_wc.append(ngrams.lemma_)
            
        matcher.add('PATTERN3', None, pattern3)
        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                if ngrams.lemma_ not in n_g and ngrams.lemma_ not in n_g1 and ngrams.lemma_ not in n_g2:
                    n_g3.append(ngrams.lemma_)
                    ngrams_ss.append(ngrams.lemma_)
                    ngrams_wc.append(ngrams.lemma_)
            
        matcher.add('PATTERN4', None, pattern4)
        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                if ngrams.lemma_ not in n_g and ngrams.lemma_ not in n_g1 and ngrams.lemma_ not in n_g2 and ngrams.lemma_ not in n_g3:
                    n_g4.append(ngrams.lemma_)
                    ngrams_ss.append(ngrams.lemma_)
                    ngrams_wc.append(ngrams.lemma_)
            
        matcher.add('PATTERN5', None, pattern5)
        if len(i) > 1:
            matches = matcher(doc)
            for match_id, start, end in matches:
                # Get the matched span
                ngrams = doc[start:end]
                if ngrams.lemma_ not in n_g and ngrams.lemma_ not in n_g1 and ngrams.lemma_ not in n_g2 and ngrams.lemma_ not in n_g3 and ngrams.lemma_ not in n_g4:
                    n_g5.append(ngrams.lemma_)
                    ngrams_ss.append(ngrams.lemma_)
                    ngrams_wc.append(ngrams.lemma_)
    
    return ngrams_ss

# %%
reviews['Ngrams'] = reviews['review_new'].apply(sp_pattern)

# %%
fdist = FreqDist(ngrams_wc)
topterms = fdist.most_common(50)

# %%
mylist = []
for a,c in topterms:
    mylist.append(a)

wordc=Counter(mylist)

wordcloud = WordCloud(stopwords=STOPWORDS, width = 1500, height = 1000,
                          background_color='white', 
                      max_words=300).generate_from_frequencies(wordc)
wordcloud.to_file("wordcloud_n_grams.png")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
df_review = reviews.groupby(['Rating']).mean()
df_review
df_review.plot(figsize=(14,8),title = 'Rating vs Polarity and Subjectivity');
